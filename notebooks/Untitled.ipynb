# %% [markdown]
# # Diagonising the source of an issue with ingesting PSI data
#
# At the time of writing this there seem to be an issue with the effective_date in property sales data.

# %%
# %cd ..

import pandas as pd

from lib.service.database import DatabaseService
from lib.service.database.defaults import DB_INSTANCE_MAP

db = DatabaseService.create(DB_INSTANCE_MAP[1], 1)
await db.wait_till_running()
engine = db.engine()

df = pd.read_sql("""
select * from nsw_lrs.legal_description
  left join meta.source_file USING (source_id)
  left join meta.source_byte_position USING (source_id, file_source_id)
  left join meta.file_source USING (file_source_id)
order by effective_date
limit 100
""", engine)

df
# Out:
# /Users/angus/code/jupyter/notebooks/20240907, vg
# /Users/angus/code/jupyter/env/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# dbname=gnaf_db port=5434 user=postgres host=localhost password=throwAwayPassword
#     file_source_id  source_id effective_date  legal_description_id  \
# 0            88943   21357909     0016-08-10               4828331
# 1            90732   21684706     0016-10-17               4861865
# 2            91009   21722663     0016-11-06               4865723
# 3            90862   21703240     0016-11-11               4863697
# 4            92273   21960597     0016-12-13               4891586
# ..             ...        ...            ...                   ...
# 95          134105   28741267     1023-04-24               5738432
# 96          135707   28977545     1023-05-11               5768783
# 97          136603   29106604     1023-09-27               5785157
# 98          142275   30021969     1023-10-24               5892948
# 99          137201   29208085     1023-11-28               5797702
#
#    legal_description legal_description_kind  property_id  \
# 0         91/1111842                initial      3316426
# 1         242/880047                initial       355483
# 2          13/203449                initial        70038
# 3          7/A/12005                initial         6422
# 4        6/15/758227                initial      2678901
# ..               ...                    ...          ...
# 95           81/6299                initial      1309308
# 96         92/253204                initial      2562548
# 97         12/247430                initial      2753309
# 98      8308/1292738                initial      4564430
# 99       137/1154120                initial      3574539
#
#     source_byte_position                                          file_path  \
# 0                   2340  _out_zip/nswvg_aps_2016/20160912/526_SALES_DAT...
# 1                   4996  _out_zip/nswvg_aps_2016/20161212/014_SALES_DAT...
# 2                  13786  _out_zip/nswvg_aps_2016/20161226/003_SALES_DAT...
# 3                     40  _out_zip/nswvg_aps_2016/20161219/001_SALES_DAT...
# 4                    288  _out_zip/nswvg_aps_2017/20170220/253_SALES_DAT...
# ..                   ...                                                ...
# 95                 13039  _out_zip/nswvg_aps_2023/20230619/260_SALES_DAT...
# 96                  4402  _out_zip/nswvg_aps_2023/20230918/224_SALES_DAT...
# 97                  2459  _out_zip/nswvg_aps_2023/20231106/257_SALES_DAT...
# 98                  4934  _out_zip/nswvg_wps_26_Aug_2024/100_SALES_DATA_...
# 99                  1671  _out_zip/nswvg_aps_2023/20231211/217_SALES_DAT...
#
#    date_recorded date_published
# 0     2024-11-18     2016-09-12
# 1     2024-11-18     2016-12-12
# 2     2024-11-18     2016-12-26
# 3     2024-11-18     2016-12-19
# 4     2024-11-18     2017-02-20
# ..           ...            ...
# 95    2024-11-18     2023-06-19
# 96    2024-11-18     2023-09-18
# 97    2024-11-18     2023-11-06
# 98    2024-11-18     2024-08-26
# 99    2024-11-18     2023-12-11
#
# [100 rows x 11 columns]
